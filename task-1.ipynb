# %% [markdown]
# GRIP-The Sparks Foundation
#
# Data Science and Business Analytics internship
#
# Prediction Using Supervised ML
#
# Author Name: Vaishnavi Darade
#
# Task-predict the percentage of students based on study hours
#
# Dataset Link-http://bit.ly/w-data

# %% [markdown]
# Importing libraries

# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing dataset

# %%
df=pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %% [markdown]
# Plotting the value of every x with respect to y

# %%
import matplotlib.pyplot as plt
for i in df:
    x = df[i]
    y = df['Scores']
    plt.scatter(x,y)
    plt.xlabel(i)
    plt.ylabel('Scores')
    plt.show()
    print("\n")

# %% [markdown]
# Heatmap

# %%
import seaborn as sns
sns.heatmap(df.corr(),cmap="PiYG")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Defining the value of x and y

# %%
x=df.drop(['Scores'],axis=1)
y=df['Scores']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 47)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression().fit(X_train,y_train)
model_Train_pred=model.predict(X_train)
model_pred=model.predict(X_test)
modelfinal=model

from sklearn.metrics import mean_absolute_error
errorstr = mean_absolute_error(y_train,model_Train_pred)
errorste = mean_absolute_error(y_test, model_pred)
print('\nmae(On train,On test)=',(errorstr,errorste))

from sklearn.metrics import r2_score
r2tr = r2_score(y_train,model_Train_pred)
r2te = r2_score(y_test, model_pred)
print('\nR2(On train,On test)=',(r2tr,r2te))
# Out:
# mae(On train,On test)= (5.138833949608738, 3.9876515607532896)
#
# R2(On train,On test)= (0.9449981421380831, 0.9521060716018698)

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor().fit(X_train,y_train)
model_Train_pred=model.predict(X_train)
model_pred=model.predict(X_test)
modelfinal=model

from sklearn.metrics import mean_absolute_error
errorstr = mean_absolute_error(y_train,model_Train_pred)
errorste = mean_absolute_error(y_test, model_pred)
print('\nmae(On train,On test)=',(errorstr,errorste))

from sklearn.metrics import r2_score
r2tr = r2_score(y_train,model_Train_pred)
r2te = r2_score(y_test, model_pred)
print('\nR2(On train,On test)=',(r2tr,r2te))
# Out:
# mae(On train,On test)= (2.5820000000000003, 3.2799999999999985)
#
# R2(On train,On test)= (0.9840592153304861, 0.9577140931152256)

# %% [markdown]
# Scaling the values

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler = MinMaxScaler()
mmscaler.fit(x)
x = mmscaler.transform(x)

# %% [markdown]
# Standardization of values

# %%
from sklearn.preprocessing import StandardScaler
sscaler = StandardScaler()
sscaler.fit(x)
x = sscaler.transform(x)

# %% [markdown]
# Train-Test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 47)

# %% [markdown]
# Random forest Classifier after scaling and standardization

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor().fit(X_train,y_train)
model_Train_pred=model.predict(X_train)
model_pred=model.predict(X_test)
modelfinal=model

from sklearn.metrics import mean_absolute_error
errorstr = mean_absolute_error(y_train,model_Train_pred)
errorste = mean_absolute_error(y_test, model_pred)
print('\nmae(On train,On test)=',(errorstr,errorste))

from sklearn.metrics import r2_score
r2tr = r2_score(y_train,model_Train_pred)
r2te = r2_score(y_test, model_pred)
print('\nR2(On train,On test)=',(r2tr,r2te))
# Out:
# mae(On train,On test)= (2.632, 3.5780000000000007)
#
# R2(On train,On test)= (0.9836172866278684, 0.9544710138414524)

# %% [markdown]
# MAE appears to be high as values are very large and prediction may vary at 1/10th, 1/100th scale. Still, observing y variables we can say this value of MAE is very less and model has very nice R2 score, so we can say that this is a very nice prediction model.

# %%
def classifier(I):
    print(I)
    I= mmscaler.transform(I)
    print(I)
    I= sscaler.transform(I)
    print(I)
    y_pred=model.predict(I)
    print(y_pred)

# %% [markdown]
# Predicting the new values

# %%
classifier([[5]])
# Out:
# [[5]]
# [[0.48148148]]
# [[-0.00485029]]
# [49.82]
